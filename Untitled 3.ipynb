# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: South Federal University
# Retrieving http://py4e-data.dr-chuck.net/json?key=42&address=South+Federal+University
# Retrieved 2291 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "short_name": "3140",
#                     "long_name": "3140",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "short_name": "S Federal St",
#                     "long_name": "South Federal Street",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "short_name": "Douglas",
#                     "long_name": "Douglas",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "Chicago",
#                     "long_name": "Chicago",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "Cook County",
#                     "long_name": "Cook County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "IL",
#                     "long_name": "Illinois",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "US",
#                     "long_name": "United States",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "60616",
#                     "long_name": "60616",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "place_id": "ChIJ9e_QQm0sDogRhUPatldEFxw",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8367719,
#                     "lng": -87.6291633
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.8381208802915,
#                         "lng": -87.62781431970849
#                     },
#                     "southwest": {
#                         "lat": 41.8354229197085,
#                         "lng": -87.6305122802915
#                     }
#                 },
#                 "location_type": "ROOFTOP"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "university"
#             ],
#             "formatted_address": "3140 S Federal St, Chicago, IL 60616, USA",
#             "plus_code": {
#                 "compound_code": "R9PC+P8 Chicago, Illinois, United States",
#                 "global_code": "86HJR9PC+P8"
#             }
#         }
#     ],
#     "status": "OK"
# }
# 3140 S Federal St, Chicago, IL 60616, USA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3_420/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     726             try:
# --> 727                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     728             except Exception:
#
# ~/anaconda3_420/lib/python3.5/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# ~/anaconda3_420/lib/python3.5/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7291)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq/backend/cython/socket.c:7089)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq/backend/cython/socket.c:2041)()
#
# ~/anaconda3_420/lib/python3.5/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/socket.c:9229)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-07b28c370f5d> in <module>()
#      20
#      21 while True:
# ---> 22     address = input('Enter location: ')
#      23     if len(address) < 1: break
#      24
#
# ~/anaconda3_420/lib/python3.5/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     700             self._parent_ident,
#     701             self._parent_header,
# --> 702             password=False,
#     703         )
#     704
#
# ~/anaconda3_420/lib/python3.5/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     730             except KeyboardInterrupt:
#     731                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 732                 raise KeyboardInterrupt
#     733             else:
#     734                 break
#
# KeyboardInterrupt:

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: South Federal University
# Retrieving http://py4e-data.dr-chuck.net/json?key=42&address=South+Federal+University
# Retrieved 2291 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "short_name": "3140",
#                     "long_name": "3140",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "short_name": "S Federal St",
#                     "long_name": "South Federal Street",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "short_name": "Douglas",
#                     "long_name": "Douglas",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "Chicago",
#                     "long_name": "Chicago",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "Cook County",
#                     "long_name": "Cook County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "IL",
#                     "long_name": "Illinois",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "US",
#                     "long_name": "United States",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "60616",
#                     "long_name": "60616",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "place_id": "ChIJ9e_QQm0sDogRhUPatldEFxw",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8367719,
#                     "lng": -87.6291633
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.8381208802915,
#                         "lng": -87.62781431970849
#                     },
#                     "southwest": {
#                         "lat": 41.8354229197085,
#                         "lng": -87.6305122802915
#                     }
#                 },
#                 "location_type": "ROOFTOP"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "university"
#             ],
#             "formatted_address": "3140 S Federal St, Chicago, IL 60616, USA",
#             "plus_code": {
#                 "compound_code": "R9PC+P8 Chicago, Illinois, United States",
#                 "global_code": "86HJR9PC+P8"
#             }
#         }
#     ],
#     "status": "OK"
# }
# lat 41.8367719 lng -87.6291633
# 3140 S Federal St, Chicago, IL 60616, USA
# Enter location: University of Delaware
# Retrieving http://py4e-data.dr-chuck.net/json?key=42&address=University+of+Delaware
# Retrieved 1809 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "short_name": "Newark",
#                     "long_name": "Newark",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "New Castle County",
#                     "long_name": "New Castle County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "DE",
#                     "long_name": "Delaware",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "US",
#                     "long_name": "United States",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "short_name": "19716",
#                     "long_name": "19716",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "place_id": "ChIJpelbVi6qx4kRceNYY0T-LsA",
#             "geometry": {
#                 "location": {
#                     "lat": 39.6779504,
#                     "lng": -75.7506114
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.6792993802915,
#                         "lng": -75.74926241970849
#                     },
#                     "southwest": {
#                         "lat": 39.6766014197085,
#                         "lng": -75.75196038029151
#                     }
#                 },
#                 "location_type": "GEOMETRIC_CENTER"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "university"
#             ],
#             "formatted_address": "Newark, DE 19716, USA",
#             "plus_code": {
#                 "compound_code": "M6HX+5Q Newark, Delaware, United States",
#                 "global_code": "87F6M6HX+5Q"
#             }
#         }
#     ],
#     "status": "OK"
# }
# lat 39.6779504 lng -75.7506114
# Newark, DE 19716, USA
